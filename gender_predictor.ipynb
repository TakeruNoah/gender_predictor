# %%
from sklearn import datasets
from sklearn.utils import Bunch
from sklearn import svm
from sklearn.metrics import accuracy_score
import csv
from random import randint
import pandas as pd
from sklearn.feature_extraction import DictVectorizer
import numpy as np

# %%
dalist=[]
da_label_list=[]

# %% [markdown]
# ## this is where i collect the data for training set

# %%
def main():
   # with open ("custom_training_data_set.csv", "a") as trainingfile:
   #    trainingfile.write("gender:\tname:\tmajor:\theight:\tweight:\thobbies:\t\n")
  
   while True:
      dadict={}
      userGender=input("what is your gender?")
      if userGender=="male":
         da_label_list.append(0)
      elif userGender=="female":
         da_label_list.append(1)
      userName=input("what is your name?")
      dadict["name"]=userName
      userMajor=input("what is your major?")
      dadict["major"]=userMajor
      userHeight=input("what is your height?")
      dadict["height"]=userHeight
      userWeight=input("what is your weight in lbs?")
      dadict["weight"]=userWeight
      userHobbies=input("what are your hobbies? (separate by comma)")
      dadict["hobbies"]=userHobbies
      dalist.append(dadict)
      final_input=input(" -- - - -----------------------  ---- ONE PERSON DONE ------ ------------------------------ --- --\npress enter to continue and EXIT to exit")
      if final_input=="EXIT":
         print(dalist)
         break
      else:
         continue
   
if __name__ == "__main__":
    main()
      
      ## get the info per user and have it write on csv 
      ## at end of user have that message 
      ##do user 1 etrc
   
   
   # with open(the filecsv)  as trainfile
    # write headings
    #then start calling classes to get all input data 
    #do a while true loop and just have the user keep inputing new people until they type EXIT or something (do break there)
    #maybe type something like -- - - ---------------- ONE PERSON DONE ------ ------------------------------ ---    --------------
    # then keep goinng. look how to do more instances of users for the training set
    # do gender as key value and all that 
    
    
    ## eventually do data of average genders in each major, then based on that have alogrithm generate instances of users based on that shit
    ## like for example if business was 50 50 male female have a thing where u choose how many users to instantiate then you make them with that statistic 
    ## or do 50 random and 50 with that stat above. ya actually do that
# Out:
# [{'gender': 'male', 'name': 'noah', 'major': 'computer science', 'height': '68', 'weight': '160', 'hobbies': 'hiking,anime,call of duty'}, {'gender': 'female', 'name': 'noel', 'major': 'business', 'height': '62', 'weight': '110', 'hobbies': 'baking,knitting'}, {'gender': 'female', 'name': 'joanne', 'major': 'business', 'height': '67', 'weight': '138', 'hobbies': 'volleyball,basketball,hiking'}, {'gender': 'male', 'name': 'meek', 'major': 'engineering', 'height': '70', 'weight': '180', 'hobbies': 'hiphop,basketball'}, {'gender': 'male', 'name': 'jack', 'major': 'art', 'height': '63', 'weight': '110', 'hobbies': 'baking,sunbathing'}, {'gender': 'female', 'name': 'helen', 'major': 'engineering', 'height': '69', 'weight': '150', 'hobbies': 'reading,shopping'}, {'gender': 'male', 'name': 'alex', 'major': 'business', 'height': '67', 'weight': '130', 'hobbies': 'knitting'}, {'gender': 'female', 'name': 'paige', 'major': 'nursing', 'height': '61', 'weight': '125', 'hobbies': 'basketball,part
# ...

# %%
for row in dalist:
    print(row)
    
print(da_label_list)
# Out:
# {'name': 'noah', 'major': 'computer science', 'height': '68', 'weight': '160', 'hobbies': 'hiking,anime,call of duty'}
# {'name': 'noel', 'major': 'business', 'height': '62', 'weight': '110', 'hobbies': 'baking,knitting'}
# {'name': 'joanne', 'major': 'business', 'height': '67', 'weight': '138', 'hobbies': 'volleyball,basketball,hiking'}
# {'name': 'meek', 'major': 'engineering', 'height': '70', 'weight': '180', 'hobbies': 'hiphop,basketball'}
# {'name': 'jack', 'major': 'art', 'height': '63', 'weight': '110', 'hobbies': 'baking,sunbathing'}
# {'name': 'helen', 'major': 'engineering', 'height': '69', 'weight': '150', 'hobbies': 'reading,shopping'}
# {'name': 'alex', 'major': 'business', 'height': '67', 'weight': '130', 'hobbies': 'knitting'}
# {'name': 'paige', 'major': 'nursing', 'height': '61', 'weight': '125', 'hobbies': 'basketball,partying,shopping'}
# {'name': 'alex', 'major': 'communications', 'height': '68', 'weight': '190', 'hobbies': 'discord'}
# ...

# %% [markdown]
# ## load the model here

# %%
clf = svm.SVC(gamma=0.001, C=100.)

# %% [markdown]
# ## fit the model here

# %%
v = DictVectorizer(sparse=False) ## this creates a vectorizer object i think. just pasted it here
X=v.fit_transform(dalist) ## here i take the data taken above and turn it into a array where the machine learning can take place 
y=da_label_list
clf.fit(X,y)
# Out:
# SVC(C=100.0, gamma=0.001)

# %%
da_testing_list=[]

# %% [markdown]
# ## load testing dataset

# %%
while True:
    dadict={}
   
    userName=input("what is your name?")
    dadict["name"]=userName
    userMajor=input("what is your major?")
    dadict["major"]=userMajor
    userHeight=input("what is your height?")
    dadict["height"]=userHeight
    userWeight=input("what is your weight in lbs?")
    dadict["weight"]=userWeight
    userHobbies=input("what are your hobbies? (separate by comma)")
    dadict["hobbies"]=userHobbies
    da_testing_list.append(dadict)
      
    final_input=input(" -- - - -----------------------  ---- ONE PERSON DONE ------ ------------------------------ --- --\npress enter to continue and EXIT to exit")
      
    if final_input=="EXIT":
        break
    else:
        continue

# %%
print(da_testing_list)
# Out:
# [{'name': 'jake', 'major': 'engineering', 'height': '68', 'weight': '155', 'hobbies': 'call of duty,football'}, {'name': 'lisa', 'major': 'art', 'height': '62', 'weight': '130', 'hobbies': 'knitting,baking'}, {'name': 'jeff', 'major': 'business', 'height': '69', 'weight': '168', 'hobbies': 'hiking,beach volleyball'}, {'name': 'claire', 'major': 'communications', 'height': '60', 'weight': '168', 'hobbies': 'dancing,sunbathing'}, {'name': 'alex', 'major': 'business', 'height': '66', 'weight': '145', 'hobbies': 'knitting'}, {'name': 'shawn', 'major': 'engineering', 'height': '69', 'weight': '169', 'hobbies': 'call of duty,football'}, {'name': 'kai', 'major': 'business', 'height': '70', 'weight': '170', 'hobbies': 'fishing,hiking'}, {'name': 'sarah', 'major': 'nursing', 'height': '64', 'weight': '130', 'hobbies': 'dancing,fortnite'}, {'name': 'jason', 'major': 'computer science', 'height': '68', 'weight': '150', 'hobbies': 'baking,football'}, {'name': 'rion', 'major': 'psycology', 'heigh
# ...

# %%
X2=v.transform(da_testing_list)

# %%
the_prediction=clf.predict(X2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/noahdemers/Documents/misc code/gender_predictor.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/Users/noahdemers/Documents/misc%20code/gender_predictor.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> the_prediction=clf.predict(X2)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:814, in BaseSVC.predict(self, X)
#     812     y = np.argmax(self.decision_function(X), axis=1)
#     813 else:
# --> 814     y = super().predict(X)
#     815 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:429, in BaseLibSVM.predict(self, X)
#     413 def predict(self, X):
#     414     """Perform regression on samples in X.
#     415
#     416     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
# ...

# %% [markdown]
# ## make the prediction and find the accuracy
